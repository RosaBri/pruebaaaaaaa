# %% [markdown]
# ## Deber de bioinformatica de mapa de ciencia G01
# ### Nombre: Rosa Briñoles

# %%
import re
import csv
import pandas as pd
import matplotlib.pyplot as pltb
import itertools

# %%
import re
with open('./pubmed-invitrofer-set.txt',"r", encoding='utf-8-sig') as f:
    my_arch = f.read()
    my_arch = re.sub(r'\n\s{6}', ' ', my_arch)

# %%
text1 = re.findall(r"\,\s[A-Z]+[A-z]{2,11}\.", my_arch)

# %%
unique_text =list(set(text1))
unique_text.sort()
a = unique_text
print(a[:20])
# Out:
# [', AMG.', ', Aberdeen.', ', Abt.', ', Adelaide.', ', Afd.', ', Alabama.', ', Aland.', ', Albany.', ', Allemagne.', ', Alta.', ', Amiens.', ', Amsterdam.', ', Angers.', ', Antananarivo.', ', Apdo.', ', Argentina.', ', Arizona.', ', Armenia.', ', Auckland.', ', Augustenstr.']

# %%
b = unique_text
b.remove(', AMG.')
b.remove(', Aberdeen.')
b.remove(', Abt.')
b.remove(', Adelaide.')
b.remove(', Afd.')
b.remove(', Alabama.')
b.remove(', Aland.')
b.remove(', Albany.')
b.remove(', Allemagne.')
b.remove(', Alta.')
b.remove(', Amiens.')
b.remove(', Amsterdam.')
b.remove(', Angers.')
b.remove(', Antananarivo.')
b.remove(', Apdo.')
b.remove(', Arizona.')
b.remove(', Auckland.')
b.remove(', Augustenstr.')

# %%
print() 
print('Países : ', b)
# Out:
# Países :  [', Argentina.', ', Armenia.', ', Austin.', ', Australia.', ', Austria.', ', Avda.', ', Bagnolet.', ', Bahrain.', ', Baldingerstr.', ', Bangladesh.', ', Bari.', ', Basel.', ', Bearsden.', ', Beijing.', ', Belfast.', ', Belgique.', ', Belgium.', ', Belgrade.', ', Benidorm.', ', Berlin.', ', Birmingham.', ', Bisceglie.', ', Bolivia.', ', Bombay.', ', Bondy.', ', Bonn.', ', Bordeaux.', ', Boston.', ', Brasil.', ', Bravelle.', ', Brazil.', ', Bregenz.', ', Bristol.', ', Brno.', ', Bruxelles.', ', Bucharest.', ', Budapest.', ', Bulgaria.', ', CEP.', ', Cagliari.', ', Cairo.', ', Calif.', ', California.', ', Cambridge.', ', Camden.', ', Cameroon.', ', Canada.', ', Cardiff.', ', Chile.', ', China.', ', Christchurch.', ', Clamart.', ', Clindigo.', ', Colorado.', ', Columbus.', ', Connecticut.', ', Copenhagen.', ', Croatia.', ', Crta.', ', Cyprus.', ', DDR.', ', Daejeon.', ', Davis.', ', Denmark.', ', Denver.', ', Dept.', ', Deutschland.', ', Div.', ', Dublin.', ', Duitsland.', ', Ecuador.', ', Egypt.', ', Empirically.', ', England.', ', Enugu.', ', Erlangen.', ', Estonia.', ', Ethiopia.', ', FRG.', ', FRS.', ', Fertil.', ', Fig.', ', Finland.', ', Florida.', ', Follistam.', ', France.', ', Frauenklinik.', ', Gainesville.', ', Georgia.', ', Germany.', ', Giessen.', ', Govt.', ', Graz.', ', Greece.', ', Groningen.', ', Guadalajara.', ', Guangzhou.', ', Gynek.', ', HHS.', ', HUS.', ', Hadera.', ', Haifa.', ', Hawaii.', ', Helsinki.', ', Houston.', ', Hubei.', ', Hungary.', ', Hyogo.', ', ICSI.', ', III.', ', ITALY.', ', Ill.', ', Illinois.', ', Inc.', ', Ind.', ', India.', ', Ind
# La de paises :  ['Argentina', 'Armenia', 'Austin', 'Australia', 'Austria', 'Avda', 'Bagnolet', 'Bahrain', 'Baldingerstr', 'Bangladesh', 'Bari', 'Basel', 'Bearsden', 'Beijing', 'Belfast', 'Belgique', 'Belgium', 'Belgrade', 'Benidorm', 'Berlin', 'Birmingham', 'Bisceglie', 'Bolivia', 'Bombay', 'Bondy', 'Bonn', 'Bordeaux', 'Boston', 'Brasil', 'Bravelle', 'Brazil', 'Bregenz', 'Bristol', 'Brno', 'Bruxelles', 'Bucharest', 'Budapest', 'Bulgaria', 'CEP', 'Cagliari', 'Cairo', 'Calif', 'California', 'Cambridge', 'Camden', 'Cameroon', 'Canada', 'Cardiff', 'Chile', 'China', 'Christchurch', 'Clamart', 'Clindigo', 'Colorado', 'Columbus', 'Connecticut', 'Copenhagen', 'Croatia', 'Crta', 'Cyprus', 'DDR', 'Daejeon', 'Davis', 'Denmark', 'Denver', 'Dept', 'Deutschland', 'Div', 'Dublin', 'Duitsland', 'Ecuador', 'Egypt', 'Empirically', 'England', 'Enugu', 'Erlangen', 'Estonia', 'Ethiopia', 'FRG', 'FRS', 'Fertil', 'Fig', 'Finland', 'Florida', 'Follistam', 'France', 'Frauenklinik', 'Gainesville', 'Georgia', 'Germany', 'Giessen', 'Govt', 'Graz', 'Greece', 'Groningen', 'Guadalajara', 'Guangzhou', 'Gynek', 'HHS', 'HUS', 'Hadera', 'Haifa', 'Hawaii', 'Helsinki', 'Houston', 'Hubei', 'Hungary', 'Hyogo', 'ICSI', 'III', 'ITALY', 'Ill', 'Illinois', 'Inc', 'Ind', 'India', 'Indiana', 'Indonesia', 'Iowa', 'Iran', 'Iraq', 'Ireland', 'Isarel', 'Israel', 'Istanbul', 'Italia', 'Italy', 'Jaboticabal', 'Jamaica', 'Japan', 'Jerusalem', 'Jiangsu', 'Jinan', 'Johannesburg', 'Jordan', 'KSA', 'Kansas', 'Kaohsiung', 'Karachi', 'Kenya', 'Kgs', 'Korea', 'Kosice', 'Kosovo', 'Kuopio', 'Kuwait', 'LLC', 'Lagos', 'Lainzerstr', 'Lausanne', 'Lebanon', 'Leeds', 'Leicester', 'Leiden', 'Leipzig', 'Leuven', 'Lille', 'Lisboa', 'Lithuania', 'Liverpool', 'Logan', 'Lok', 'London', 'Louisiana', 'Ltd', 'Lund', 'Lyon', 'Madrid', 'Malayasia', 'Malaysia', 'Malta', 'Manchester', 'Marseille', 'Maryland', 'Mass', 'Massahusetts', 'Medikamente', 'Melbourne', 'Memphis', 'Mexico', 'Mich', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Moorenstr', 'Mrs', 'NIH', 'Nantes', 'Napoli', 'Nedlands', 'Nepal', 'Netherlands', 'Neustadt', 'Nevada', 'Newark', 'Nice', 'Nigeria', 'Nijmegen', 'Nis', 'Norfolk', 'Norway', 'Nottingham', 'Nouzilly', 'OYS', 'Ohio', 'Ohnhorststr', 'Oklahoma', 'Olomouc', 'Ont', 'Ontario', 'Oregon', 'Oslo', 'Osp', 'Ostrava', 'Oxford', 'PESA', 'Pakistan', 'Paris', 'Pavia', 'Pennsylvania', 'Perth', 'Peru', 'Philadelphia', 'Pilsen', 'Pol', 'Poland', 'Police', 'Polska', 'Portland', 'Portugal', 'Prague', 'Praha', 'Pretoria', 'Prittwitzstr', 'PureSperm', 'Qatar', 'Que', 'Queensland', 'ROC', 'RSA', 'Raleigh', 'Rennes', 'Retired', 'Richmond', 'Rize', 'Roma', 'Romania', 'Rome', 'Russia', 'Salzburg', 'Santiago', 'Scandinavia', 'Scotland', 'Seattle', 'Sec', 'Serbia', 'Singapore', 'Slovenia', 'Spain', 'Srbija', 'Ste', 'Stockholm', 'Strasbourg', 'Sudan', 'Suisse', 'Sweden', 'Switzerland', 'Taipei', 'Taiwan', 'Taiyuan', 'Temple', 'Tex', 'Texas', 'Thailand', 'Tilburg', 'Tokyo', 'Toronto', 'Toulouse', 'Tunisia', 'Turkey', 'Turku', 'UAE', 'USA', 'Ukraine', 'Ulm', 'Univ', 'Uppsala', 'Uruguay', 'Utah', 'Utrecht', 'VIC', 'Vic', 'Victoria', 'Vietnam', 'Villeurbanne', 'Vilvoorde', 'Virginia', 'Wales', 'Warszawa', 'Washington', 'Weinheim', 'Wien', 'Wisconsin', 'Wuhan', 'Yugoslavia', 'Yunnan']

# %%
data = pd.read_csv('./Paises_ubicacion.csv', engine='python', skipfooter=3)
data.head(10)
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla
# 5      AL  41.153332  20.168331               Albania
# 6      AM  40.069099  45.038189               Armenia
# 7      AN  12.226079 -69.060087  Netherlands Antilles
# 8      AO -11.202692  17.873887                Angola
# 9      AQ -75.250973  -0.071389            Antarctica

# %%
name = data[data.name.isin(g)]
name.head(10)
# Out:
#    country   latitude   longitude        name
# 6       AM  40.069099   45.038189     Armenia
# 10      AR -38.416097  -63.616672   Argentina
# 12      AT  47.516231   14.550072     Austria
# 13      AU -25.274398  133.775136   Australia
# 18      BD  23.684994   90.356331  Bangladesh
# 19      BE  50.503887    4.469936     Belgium
# 21      BG  42.733883   25.485830    Bulgaria
# 22      BH  25.930414   50.637772     Bahrain
# 27      BO -16.290154  -63.588653     Bolivia
# 28      BR -14.235004  -51.925280      Brazil

# %%
paises = data[data.country.isin(g)]
all_data =pd.concat([name,paises]).drop_duplicates().sort_values('name')
all_data.head(10)
# Out:
#    country   latitude   longitude        name
# 10      AR -38.416097  -63.616672   Argentina
# 6       AM  40.069099   45.038189     Armenia
# 13      AU -25.274398  133.775136   Australia
# 12      AT  47.516231   14.550072     Austria
# 22      BH  25.930414   50.637772     Bahrain
# 18      BD  23.684994   90.356331  Bangladesh
# 19      BE  50.503887    4.469936     Belgium
# 27      BO -16.290154  -63.588653     Bolivia
# 28      BR -14.235004  -51.925280      Brazil
# 21      BG  42.733883   25.485830    Bulgaria

# %%
import matplotlib.pyplot as plt

# %%
pltb.scatter(all_data.longitude, all_data.latitude, s=50, c=all_data.latitude)
pltb.colorbar()
ard = dict(arrowstyle="->")

pltb.annotate('Ucrania', xy = (31.16558,48.379433), 
               xytext = (31.16558,51), arrowprops= ard)

pltb.annotate('EEUU', xy = (-95.712891, 37.09024), 
               xytext = (-95.712891, 40), arrowprops = ard)

pltb.annotate('Brasil', xy = (-51.92528, -14.235004), 
               xytext = (-51.92528, -11), arrowprops= ard)
pltb.annotate('Australia', xy = (133.775136, -25.274398), 
               xytext = (133.775136, -22), arrowprops= ard)

pltb.annotate('Noruega', xy = (8.468946, 60.472024), 
               xytext = (8.468946, 63), arrowprops= ard)

pltb.annotate('China', xy = (104.195397, 35.86166), 
               xytext = (104.195397, 39), arrowprops= ard)

params = pltb.gcf()
plSize = params.get_size_inches()
params.set_size_inches( (plSize[0] * 3, plSize[1] * 3) )

pltb.savefig("Mapa de ciencia.png")
